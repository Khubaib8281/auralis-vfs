# %%
from auralis.scorer import score_audio

audio_path = "sample.wav"

score = score_audio(audio_path)
print(f"Vocal Fatigue Score: {score:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from scorer import score_audio
#       3 audio_path = "sample.wav"
#       5 score = score_audio(audio_path)
#
# ModuleNotFoundError: No module named 'scorer'
