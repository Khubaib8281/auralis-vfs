# %%
from auralis.scorer import score_audio

audio_path = "/mnt/d/code/AI/vocal_fatigue_detection_research/voices/sample.wav"

score = score_audio(audio_path)
print(f"Vocal Fatigue Score: {score:.2f}")
# Out:
# ECAPA input shape:  torch.Size([1, 313, 80])
# Vocal Fatigue Score: 46.79

# %%
pip show auralis_vfs
# Out:
# Name: auralis-vfs
# Version: 0.1.0
# Summary: Objective vocal fatigue scoring from speech using ECAPA-TDNN-VHE embeddings
# Home-page: https://github.com/Khubaib01/auralis-vocal-fatigue
# Author: "Muhammad Khubaib Ahmad"
# Author-email: Muhammad Khubaib Ahmad <muhammadkhubaibahmad854@gmail.com>
# License: MIT
# Location: /home/khubaib/miniconda3/envs/ml/lib/python3.10/site-packages
# Editable project location: /home/khubaib/projects/vocal_fatigue_scoring/auralis_vfs
# Requires: numpy, pydub, scipy, soundfile, torch, torchaudio
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
